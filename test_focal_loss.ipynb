# %%
# import focal loss from torchvision
from torchvision.ops import sigmoid_focal_loss
from torchvision.ops import focal_loss

# %%
from azureml.core import Workspace, Dataset, Datastore
subscription_id = 'f8c5aac3-29fc-4387-858a-1f61722fb57a'
resource_group = 'forskerpl-n0ybkr-rg'
workspace_name = 'forskerpl-n0ybkr-mlw'
  
workspace = Workspace(subscription_id, resource_group, workspace_name)
  

import os
from os.path import join

# %%
import numpy as np
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.lines as mlines
import matplotlib.transforms as mtransforms
import scipy
import pandas as pd
import torch

# %%
# use fold_0 - fold_9 as train/val/test in turn
# train: 012345 / 234567 / 456789 / 678901 / 890123
# val: 67 / 89 / 01 / 23 / 45
# test: 89 / 01 / 23 / 45 / 67
# save pids for each fold

# get all pids
pids = torch.load('../10_fold/fold_0.pt')
for i in range(1, 10):
    # AttributeError: 'numpy.ndarray' object has no attribute 'extend'
    # pids.extend(torch.load(f'10_fold/fold_{i}.pt'))
    # do not use extend
    pids = np.concatenate((pids, torch.load(f'../10_fold/fold_{i}.pt')))
torch.save(pids, '../intraining_5_folds/pids.pt')
# pids = torch.load('../cv_split/pids.pt')
# fold_0
pids_train = torch.load('./10_fold/fold_0.pt')
pids_train = np.concatenate((pids_train, torch.load('../10_fold/fold_1.pt')))
pids_train = np.concatenate((pids_train, torch.load('../10_fold/fold_2.pt')))
pids_train = np.concatenate((pids_train, torch.load('../10_fold/fold_3.pt')))
pids_train = np.concatenate((pids_train, torch.load('../10_fold/fold_4.pt')))
pids_train = np.concatenate((pids_train, torch.load('../10_fold/fold_5.pt')))
pids_val = torch.load('../10_fold/fold_6.pt')
pids_val = np.concatenate((pids_val, torch.load('../10_fold/fold_7.pt')))
pids_test = torch.load('../10_fold/fold_8.pt')
pids_test = np.concatenate((pids_test, torch.load('../10_fold/fold_9.pt')))
# save
torch.save(pids_train, '../intraining_5_folds/fold_0/pids_train.pt')
torch.save(pids_val, '../intraining_5_folds/fold_0/pids_val.pt')
torch.save(pids_test, '../intraining_5_folds/fold_0/pids_test.pt')

# fold_1
pids_train = torch.load('../10_fold/fold_2.pt')
pids_train = np.concatenate((pids_train, torch.load('../10_fold/fold_3.pt')))
pids_train = np.concatenate((pids_train, torch.load('../10_fold/fold_4.pt')))
pids_train = np.concatenate((pids_train, torch.load('../10_fold/fold_5.pt')))
pids_train = np.concatenate((pids_train, torch.load('../10_fold/fold_6.pt')))
pids_train = np.concatenate((pids_train, torch.load('../10_fold/fold_7.pt')))
pids_val = torch.load('../10_fold/fold_8.pt')
pids_val = np.concatenate((pids_val, torch.load('../10_fold/fold_9.pt')))
pids_test = torch.load('../10_fold/fold_0.pt')
pids_test = np.concatenate((pids_test, torch.load('../10_fold/fold_1.pt')))
# save
torch.save(pids_train, '../intraining_5_folds/fold_1/pids_train.pt')
torch.save(pids_val, '../intraining_5_folds/fold_1/pids_val.pt')
torch.save(pids_test, '../intraining_5_folds/fold_1/pids_test.pt')

# fold_2
pids_train = torch.load('../10_fold/fold_4.pt')
pids_train = np.concatenate((pids_train, torch.load('../10_fold/fold_5.pt')))
pids_train = np.concatenate((pids_train, torch.load('../10_fold/fold_6.pt')))
pids_train = np.concatenate((pids_train, torch.load('../10_fold/fold_7.pt')))
pids_train = np.concatenate((pids_train, torch.load('../10_fold/fold_8.pt')))
pids_train = np.concatenate((pids_train, torch.load('../10_fold/fold_9.pt')))
pids_val = torch.load('../10_fold/fold_0.pt')
pids_val = np.concatenate((pids_val, torch.load('../10_fold/fold_1.pt')))
pids_test = torch.load('../10_fold/fold_2.pt')
pids_test = np.concatenate((pids_test, torch.load('../10_fold/fold_3.pt')))
# save
torch.save(pids_train, '../intraining_5_folds/fold_2/pids_train.pt')
torch.save(pids_val, '../intraining_5_folds/fold_2/pids_val.pt')
torch.save(pids_test, '../intraining_5_folds/fold_2/pids_test.pt')

# fold_3
pids_train = torch.load('../10_fold/fold_6.pt')
pids_train = np.concatenate((pids_train, torch.load('../10_fold/fold_7.pt')))
pids_train = np.concatenate((pids_train, torch.load('../10_fold/fold_8.pt')))
pids_train = np.concatenate((pids_train, torch.load('../10_fold/fold_9.pt')))
pids_train = np.concatenate((pids_train, torch.load('../10_fold/fold_0.pt')))
pids_train = np.concatenate((pids_train, torch.load('../10_fold/fold_1.pt')))
pids_val = torch.load('../10_fold/fold_2.pt')
pids_val = np.concatenate((pids_val, torch.load('../10_fold/fold_3.pt')))
pids_test = torch.load('../10_fold/fold_4.pt')
pids_test = np.concatenate((pids_test, torch.load('../10_fold/fold_5.pt')))
# save
torch.save(pids_train, '../intraining_5_folds/fold_3/pids_train.pt')
torch.save(pids_val, '../intraining_5_folds/fold_3/pids_val.pt')
torch.save(pids_test, '../intraining_5_folds/fold_3/pids_test.pt')

# fold_4
pids_train = torch.load('../10_fold/fold_8.pt')
pids_train = np.concatenate((pids_train, torch.load('../10_fold/fold_9.pt')))
pids_train = np.concatenate((pids_train, torch.load('../10_fold/fold_0.pt')))
pids_train = np.concatenate((pids_train, torch.load('../10_fold/fold_1.pt')))
pids_train = np.concatenate((pids_train, torch.load('../10_fold/fold_2.pt')))
pids_train = np.concatenate((pids_train, torch.load('../10_fold/fold_3.pt')))
pids_val = torch.load('../10_fold/fold_4.pt')
pids_val = np.concatenate((pids_val, torch.load('../10_fold/fold_5.pt')))
pids_test = torch.load('../10_fold/fold_6.pt')
pids_test = np.concatenate((pids_test, torch.load('../10_fold/fold_7.pt')))
# save
torch.save(pids_train, '../intraining_5_folds/fold_4/pids_train.pt')
torch.save(pids_val, '../intraining_5_folds/fold_4/pids_val.pt')
torch.save(pids_test, '../intraining_5_folds/fold_4/pids_test.pt')

# %%
# use fold_0 - fold_9 as train/val/test/calibrate in turn
# train: 0 1 2 3 / 2 3 4 5 / 4 5 6 7 / 6 7 8 9 / 8 9 0 1
# val: 4 / 6 / 8 / 0 / 2
# test: 5 6 / 7 8 / 9 0 / 1 2 / 3 4
# calibrate: 7 8 9 / 9 0 1 / 1 2 3 / 3 4 5 / 5 6 7
# save pids for each fold

# get all pids
pids = torch.load('10_fold/fold_0.pt')
for i in range(1, 10):
    # AttributeError: 'numpy.ndarray' object has no attribute 'extend'
    # pids.extend(torch.load(f'10_fold/fold_{i}.pt'))
    # do not use extend
    pids = np.concatenate((pids, torch.load(f'10_fold/fold_{i}.pt')))
torch.save(pids, 'cv_split/pids.pt')

# fold_0
pids_train = torch.load('10_fold/fold_0.pt')
pids_train = np.concatenate((pids_train, torch.load('10_fold/fold_1.pt')))
pids_train = np.concatenate((pids_train, torch.load('10_fold/fold_2.pt')))
pids_train = np.concatenate((pids_train, torch.load('10_fold/fold_3.pt')))
pids_val = torch.load('10_fold/fold_4.pt')
pids_test = torch.load('10_fold/fold_5.pt')
pids_test = np.concatenate((pids_test, torch.load('10_fold/fold_6.pt')))
pids_calibrate = torch.load('10_fold/fold_7.pt')
pids_calibrate = np.concatenate((pids_calibrate, torch.load('10_fold/fold_8.pt')))
pids_calibrate = np.concatenate((pids_calibrate, torch.load('10_fold/fold_9.pt')))
# save
torch.save(pids_train, 'cv_split/fold_0/pids_train.pt')
torch.save(pids_val, 'cv_split/fold_0/pids_val.pt')
torch.save(pids_test, 'cv_split/fold_0/pids_test.pt')
torch.save(pids_calibrate, 'cv_split/fold_0/pids_calibrate.pt')

# fold_1
pids_train = torch.load('10_fold/fold_2.pt')
pids_train = np.concatenate((pids_train, torch.load('10_fold/fold_3.pt')))
pids_train = np.concatenate((pids_train, torch.load('10_fold/fold_4.pt')))
pids_train = np.concatenate((pids_train, torch.load('10_fold/fold_5.pt')))
pids_val = torch.load('10_fold/fold_6.pt')
pids_test = torch.load('10_fold/fold_7.pt')
pids_test = np.concatenate((pids_test, torch.load('10_fold/fold_8.pt')))
pids_calibrate = torch.load('10_fold/fold_9.pt')
pids_calibrate = np.concatenate((pids_calibrate, torch.load('10_fold/fold_0.pt')))
pids_calibrate = np.concatenate((pids_calibrate, torch.load('10_fold/fold_1.pt')))
# save
torch.save(pids_train, 'cv_split/fold_1/pids_train.pt')
torch.save(pids_val, 'cv_split/fold_1/pids_val.pt')
torch.save(pids_test, 'cv_split/fold_1/pids_test.pt')
torch.save(pids_calibrate, 'cv_split/fold_1/pids_calibrate.pt')

# fold_2
pids_train = torch.load('10_fold/fold_4.pt')
pids_train = np.concatenate((pids_train, torch.load('10_fold/fold_5.pt')))
pids_train = np.concatenate((pids_train, torch.load('10_fold/fold_6.pt')))
pids_train = np.concatenate((pids_train, torch.load('10_fold/fold_7.pt')))
pids_val = torch.load('10_fold/fold_8.pt')
pids_test = torch.load('10_fold/fold_9.pt')
pids_test = np.concatenate((pids_test, torch.load('10_fold/fold_0.pt')))
pids_calibrate = torch.load('10_fold/fold_1.pt')
pids_calibrate = np.concatenate((pids_calibrate, torch.load('10_fold/fold_2.pt')))
pids_calibrate = np.concatenate((pids_calibrate, torch.load('10_fold/fold_3.pt')))
# save
torch.save(pids_train, 'cv_split/fold_2/pids_train.pt')
torch.save(pids_val, 'cv_split/fold_2/pids_val.pt')
torch.save(pids_test, 'cv_split/fold_2/pids_test.pt')
torch.save(pids_calibrate, 'cv_split/fold_2/pids_calibrate.pt')

# fold_3
pids_train = torch.load('10_fold/fold_6.pt')
pids_train = np.concatenate((pids_train, torch.load('10_fold/fold_7.pt')))
pids_train = np.concatenate((pids_train, torch.load('10_fold/fold_8.pt')))
pids_train = np.concatenate((pids_train, torch.load('10_fold/fold_9.pt')))
pids_val = torch.load('10_fold/fold_0.pt')
pids_test = torch.load('10_fold/fold_1.pt')
pids_test = np.concatenate((pids_test, torch.load('10_fold/fold_2.pt')))
pids_calibrate = torch.load('10_fold/fold_3.pt')
pids_calibrate = np.concatenate((pids_calibrate, torch.load('10_fold/fold_4.pt')))
pids_calibrate = np.concatenate((pids_calibrate, torch.load('10_fold/fold_5.pt')))
# save
torch.save(pids_train, 'cv_split/fold_3/pids_train.pt')
torch.save(pids_val, 'cv_split/fold_3/pids_val.pt')
torch.save(pids_test, 'cv_split/fold_3/pids_test.pt')
torch.save(pids_calibrate, 'cv_split/fold_3/pids_calibrate.pt')

# fold_4
pids_train = torch.load('10_fold/fold_8.pt')
pids_train = np.concatenate((pids_train, torch.load('10_fold/fold_9.pt')))
pids_train = np.concatenate((pids_train, torch.load('10_fold/fold_0.pt')))
pids_train = np.concatenate((pids_train, torch.load('10_fold/fold_1.pt')))
pids_val = torch.load('10_fold/fold_2.pt')
pids_test = torch.load('10_fold/fold_3.pt')
pids_test  = np.concatenate((pids_test, torch.load('10_fold/fold_4.pt')))
pids_calibrate = torch.load('10_fold/fold_5.pt')
pids_calibrate = np.concatenate((pids_calibrate, torch.load('10_fold/fold_6.pt')))
pids_calibrate = np.concatenate((pids_calibrate, torch.load('10_fold/fold_7.pt')))
# save
torch.save(pids_train, 'cv_split/fold_4/pids_train.pt')
torch.save(pids_val, 'cv_split/fold_4/pids_val.pt')
torch.save(pids_test, 'cv_split/fold_4/pids_test.pt')
torch.save(pids_calibrate, 'cv_split/fold_4/pids_calibrate.pt')
